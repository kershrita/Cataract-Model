# %%
from Main import ParasiteDetector

# %%
detector = ParasiteDetector("runs/train-100epoch/weights/best.pt", 0.8)

# %%
detector.detect_parasites("data/images/test/", "data/images/detection/")
# Out:
# 0: 448x640 1 Cataract, 225.1ms
# Speed: 6.5ms preprocess, 225.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Cataract (1).png Done!
#
# 0: 416x640 1 Cataract, 186.6ms
# Speed: 3.0ms preprocess, 186.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Cataract (10).png Done!
#
# 0: 448x640 1 Cataract, 238.1ms
# Speed: 5.0ms preprocess, 238.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Cataract (11).png Done!
#
# 0: 448x640 1 Cataract, 386.2ms
# Speed: 3.0ms preprocess, 386.2ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Cataract (12).png Done!
#
# 0: 448x640 1 Cataract, 348.2ms
# Speed: 5.0ms preprocess, 348.2ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Cataract (13).png Done!
#
# 0: 448x640 1 Cataract, 404.7ms
# Speed: 6.0ms preprocess, 404.7ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Cataract (14).png Done!
#
# 0: 448x640 1 Cataract, 271.4ms
# ...

# %%
detector.crop_parasites("data/images/test/", "data/images/detection_cropped/")
# Out:
# 0: 448x640 1 Cataract, 266.1ms
# Speed: 10.5ms preprocess, 266.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Cataract (1).png Cropped and Saved to data/images/detection_cropped/Cataract!
#
# 0: 416x640 1 Cataract, 329.6ms
# Speed: 4.0ms preprocess, 329.6ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Cataract (10).png Cropped and Saved to data/images/detection_cropped/Cataract!
#
# 0: 448x640 1 Cataract, 344.6ms
# Speed: 6.0ms preprocess, 344.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Cataract (11).png Cropped and Saved to data/images/detection_cropped/Cataract!
#
# 0: 448x640 1 Cataract, 261.6ms
# Speed: 5.0ms preprocess, 261.6ms inference, 4.0ms postprocess per image at shape (1, 3, 448, 640)
# Cataract (12).png Cropped and Saved to data/images/detection_cropped/Cataract!
#
# 0: 448x640 1 Cataract, 282.6ms
# Speed: 4.0ms preprocess, 282.6ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# ...
